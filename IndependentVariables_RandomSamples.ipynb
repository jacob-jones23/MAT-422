# %% [markdown]
# <a href="https://colab.research.google.com/github/jacob-jones23/MAT-422/blob/main/IndependentVariables_RandomSamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**2.3 Independent Variables and Random Samples**
#
# ##**2.3.1 Joint Probability Distributions**
# In real life, we are often interested in several random variables that are related to each other. Joint probability is the probability of two or more events happening together. A joint probability distribution shows a probability distribution for two (or more) random variables.
#
# **2.3.1.1 Two Discrete Random Variables**
# The probability mass function (pmf) of a single discrete random variable *X* can be extended to two variables *X, Y* for describing how much probability mass is placed on each possible pair of values (*x,y*).
#
# **Definition 2.3.1** Let *X* and *Y* be two discrete random variable's defined on the sample space *S* of an experiment. The joint probability mass function *p(x,y)* is defined for each pair of numbers *(x,y)* by
# \begin{align}
# p(x,y) = P(X=x \text{ and } Y=y)
# \end{align}
# It must be the case that *p(x,y)* ≥ 0 and ∑$_{x}$∑$_{y}$* p(x,y)* = 1.
#
# The marginal distribution of a subset of a collection of random variables is the probability distribution of the variables contained in the subset without reference to the values of the other variable.
#
# **Definition 2.3.2** The marginal probability mass function of *X*, denoted by *p$_{X}$(x)*, is given by
# \begin{align}
# p_{X}(x) = \sum_{y:p(x,y)>0}p(x,y) \text{ for each possible value x}
# \end{align}
#
# Similarly, the marginal probability mass function of *Y* is
# \begin{align}
# p_{Y}(y) = \sum_{x:p(x,y)>0}p(x,y) \text{ for each possible value y}
# \end{align}

# %%
# !pip install prob140

# %%
from datascience import *
from prob140 import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('fivethirtyeight')

# %%
# Create a table
dist = Table().domain(make_array(2, 3), np.arange(1, 6, 2))

# Assign values using .probability()
dist = dist.probability([0.1, 0.1, 0.2, 0.3, 0.1, 0.2])
print(dist)
# Out:
#      X=2  X=3
# Y=5  0.2  0.2
# Y=3  0.1  0.1
# Y=1  0.1  0.3
# /usr/local/lib/python3.10/dist-packages/prob140/single_variable.py:350: UserWarning: .probability() is deprecated - please use .probabilities()
#   warnings.warn('.probability() is deprecated - please use .probabilities()')

# %% [markdown]
# **2.3.1.2 Two Continuous Random Variables**
# The joint continuous distribution is the continuous analogue of a joint discrete distribution.
#
# **Definition 2.3.3** Let *X* and *Y* be continuous random variables. A joint probability density function *f(x,y)* for these two variables is a function satisfying *f(x,y)* ≥ 0 and $∫_{-∞}^{∞}$ $∫_{-∞}^{∞}$*f(x,y)dxdy* = 1. Then for any two-dimensional set *A*
# \begin{align}
# P[(X,Y)∈A] = ∫∫_{A}f(x,y)dxdy
# \end{align}
# In particular, if *A* is the two-dimensional rectangle {*(x,y)*:*a ≤ x ≤ b*, *c ≤ y ≤ d*} then
# \begin{align}
# P[(X,Y)∈A] = P(a≤X≤b,c≤Y≤d) =
# ∫_{a}^{b}∫_{c}^{d}f(x,y)dydx
# \end{align}

# %%
heads_table = Table().domain("H1",[0.2,0.9],"H2",[2,1,0]).probability(make_array(.75*.04, .75*.32,.75*.64,.25*.81,.25*.18,.25*.01))
heads_table
# Out:
# /usr/local/lib/python3.10/dist-packages/prob140/single_variable.py:350: UserWarning: .probability() is deprecated - please use .probabilities()
#   warnings.warn('.probability() is deprecated - please use .probabilities()')
#       H1=0.2  H1=0.9
# H2=2    0.03  0.2025
# H2=1    0.24  0.0450
# H2=0    0.48  0.0025

# %%
coins_table = Table().domain("Coin1",['H','T'],"Coin2", ['H','T']).probability(np.array([0.24, 0.36, 0.16, 0.24]))
coins_table
# Out:
# /usr/local/lib/python3.10/dist-packages/prob140/single_variable.py:350: UserWarning: .probability() is deprecated - please use .probabilities()
#   warnings.warn('.probability() is deprecated - please use .probabilities()')
#          Coin1=H  Coin1=T
# Coin2=T     0.36     0.24
# Coin2=H     0.24     0.16

# %%
def joint_fuction(dice1, dice2):
  return (dice1 + dice2)/252

# %%
dice = Table().domain("D1", np.arange(1,7),"D2", np.arange(1,7)).probability_function(joint_fuction)
dice
# Out:
#           D1=1      D1=2      D1=3      D1=4      D1=5      D1=6
# D2=6  0.027778  0.031746  0.035714  0.039683  0.043651  0.047619
# D2=5  0.023810  0.027778  0.031746  0.035714  0.039683  0.043651
# D2=4  0.019841  0.023810  0.027778  0.031746  0.035714  0.039683
# D2=3  0.015873  0.019841  0.023810  0.027778  0.031746  0.035714
# D2=2  0.011905  0.015873  0.019841  0.023810  0.027778  0.031746
# D2=1  0.007937  0.011905  0.015873  0.019841  0.023810  0.027778

# %% [markdown]
# **Definition 2.3.4** The marginal probability density functions of *X* and *Y*, denoted by f$_{X}$(*x*) and f$_{Y}$(*y*), respectively, are given by
# \begin{align}
# f_{X}(x) = ∫_{-∞}^{∞}f(x,y)dy \text{ for } -∞ < x < ∞
# f_{Y}(y) = ∫_{-∞}^{∞}f(x,y)dx \text{ for } -∞ < y < ∞
# \end{align}

# %%
heads_table.marginal("H1")
# Out:
#                      H1=0.2  H1=0.9
# H2=2                   0.03  0.2025
# H2=1                   0.24  0.0450
# H2=0                   0.48  0.0025
# Sum: Marginal of H1    0.75  0.2500

# %%
heads_table.marginal("H2")
# Out:
#       H1=0.2  H1=0.9  Sum: Marginal of H2
# H2=2    0.03  0.2025               0.2325
# H2=1    0.24  0.0450               0.2850
# H2=0    0.48  0.0025               0.4825

# %%
coins_table.marginal("Coin1")
# Out:
#                         Coin1=H  Coin1=T
# Coin2=T                    0.36     0.24
# Coin2=H                    0.24     0.16
# Sum: Marginal of Coin1     0.60     0.40

# %%
heads_table.both_marginals()
# Out:
#                      H1=0.2  H1=0.9  Sum: Marginal of H2
# H2=2                   0.03  0.2025               0.2325
# H2=1                   0.24  0.0450               0.2850
# H2=0                   0.48  0.0025               0.4825
# Sum: Marginal of H1    0.75  0.2500               1.0000

# %%
coins_table.both_marginals()
# Out:
#                         Coin1=H  Coin1=T  Sum: Marginal of Coin2
# Coin2=T                    0.36     0.24                     0.6
# Coin2=H                    0.24     0.16                     0.4
# Sum: Marginal of Coin1     0.60     0.40                     1.0

# %%
heads_table.marginal_dist("H1")
# Out:
# Value | Probability
# 0.2   | 0.75
# 0.9   | 0.25

# %%
Plot(heads_table.marginal_dist("H1"), width=0.1)

# %%
heads_table.marginal_dist("H2")
# Out:
# Value | Probability
# 0     | 0.4825
# 1     | 0.285
# 2     | 0.2325

# %%
coins_table.marginal_dist("Coin1")
# Out:
# Value | Probability
# H     | 0.6
# T     | 0.4

# %% [markdown]
# **2.3.1.3 Independent Random Variables**
#
# **Definition 2.3.5** Two random variables *X* and *Y* are said to be independent if for every pair of *x* and *y* values
# \begin{align}
# p(x,y) = p_{X}(x)⋅p_{Y}(y) \text{ when X and Y are discrete}
# \end{align}
# or
# \begin{align}
# f(x,y) = f_{X}(x)⋅f_{Y}(y) \text{ when X and Y are continuous}
# \end{align}
# If the above is not satisfied for all *(x,y)*, then *X* and *Y* are said to be dependent.
#
# **Definition 2.3.6** If *X$_{1}$*, *X$_{2}$*,..., *X$_{n}$* are all discrete random variables, the joint pmf of the variables is the function
# \begin{align}
# p(x_{1},x_{2},...,x_{n}) = P(X_{1}=x_{1}, X_{2} = x_{2},..., X_{n} = x_{n})
# \end{align}
# If the variables are continuous, the joint pdf of *X$_{1}$,...,X$_{n}$* is the function *f(x$_{1}$, x$_{2}$,..., x$_{n}$)* such that for any *n* intervals [*a$_{1}$,b$_{1}$*],...,[*a$_{n}$,b$_{n}$*],
# \begin{align}
# P(a_{1} ≤ X_{1} ≤ b_{1},..., a_{n} ≤ X_{n} ≤ b_{n})
# \end{align}
#
# **Definition 2.3.7** The random variables *X$_{1}$, X$_{2}$,...,X$_{n}$* are said to be independent if for every subset *X$_{i_{1}}$,X$_{i_{2}}$,...,X$_{i_{k}}$* of the variables (each pair, each triple, and so on), the joint pmf or pdf of the subset is equal to the product of the marginal pmf's or pdf's.

# %%
import random
random_generator = random.Random()
random_generator.random()
# Out:
# 0.3006009667060018

# %%
import numpy as np
prng1 = np.random.RandomState()
prng2 = np.random.RandomState()
prng1.seed(1)
prng2.seed(2)

# %% [markdown]
# ##**2.3.2 Correlation and Dependence**
#
# **2.3.2.1 Correlation for Random Variables**
# When two random variables *X* and *Y* are not independent, it is frequently of interest to assess how strongly they are related to one another.

# %%
# generate related variables
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10*randn(1000)+50)
# summarize
print('data1: mean=%.3f stdv =%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv =%.3f' % (mean(data2), std(data2)))
# plot
pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=100.776 stdv =19.620
# data2: mean=151.050 stdv =22.358

# %% [markdown]
# **Definition 2.3.8** Let *X* and *Y* be jointly distributed random variable's with pmf *p(x,y)* or pdf *f(x,y)* according to whether thee variables are discrete or continuous. The covariance between two random variable's *X* and *Y* is
# \begin{align}
# Cov(X,Y) = E[(X-μ_{X})(Y-μ_{Y})]
#          = \left\{
#         \begin{array}{cl}
#         ∑_{X}∑_{Y}(x-μ_{X})(y-μ_{Y})p(x,y), \text{X,Y discrete} \\
#         \int_{-∞}^{∞}\int_{-∞}^{∞}(x-\mu_{X})(y-μ_{Y})f(x,y)dxdy, \text{X,Y continuous}
#         \end{array}
#         \right.
# \end{align}

# %%
from numpy import cov
covariance = cov(data1, data2)
print(covariance)
# Out:
# [[385.33297729 389.7545618 ]
#  [389.7545618  500.38006058]]

# %% [markdown]
# **Definition 2.3.9** The correlation coefficient of *X* and *Y*, denoted by Corr(*X,Y*), ρ$_{X,Y}$, or just ρ, is defined by
# \begin{align}
# \rho_{X,Y} = \frac {\text{Cov}(X,Y)} {\sigma_{X}⋅\sigma_{Y}}
# \end{align}
#
# **Proposition 2.3.10** Correlation coefficients have the following properties:
# 1. If *X* and *Y* are independent, then ρ = 0 but ρ = 0 does not imply independence.
# 2. |ρ| ≤ 1, ρ = 1 or -1 if *Y* = *aX* + *b* for some numbers *a* and *b* with *a* $\!=$ 0

# %%
# calculating the Pearson's correlation between two variables
from numpy.random import randn
from numpy.random import seed
from scipy.stats import pearsonr
#seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10*randn(1000)+ 50)
# calculate pearson's correlation
corr, _ = pearsonr(data1, data2)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.888

# %%
# Calculate the spearmans's correlation between two variables
from numpy.random import randn
from numpy.random import seed
from scipy.stats import spearmanr
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10*randn(1000) + 50)
# calculate spearman's correlation
corr, _ = spearmanr(data1, data2)
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: 0.872

# %% [markdown]
# **2.3.2.2 Correlation For Samples**
# Correlation coefficient, when applied to a sample, is commonly represented by *r$_{xy}$ and may be referred to as the sample correlation coefficient or the sample Pearson correlation coefficient.
#
# **Proposition 2.3.11** The correlation coefficient for samples has the following properties:
# \begin{align}
# · r_{xy} = \frac{s_{xy}} {s_{x}s_{y}} \text{ where the sample covariance }
# s_{xy} = \frac{1} {n-1} \sum_{i=1}^{n}(x_{i}-\bar{x})(y_{i}-\bar{y})
# \end{align}
# and the sample standard deviation
# \begin{align}
# s_{x} = \sqrt{\frac{1}{n-1}\sum_{i=1}^{n}(x_{i}-\bar{x})^2}
# \end{align}
#
#   * If *y* = *ax* + *b*, then *r$_{xy}$ = 1 0r -1 if *a* is positive or negative
#
# ##**2.3.3 Random Samples**
# **2.3.3.1 Random Samples**
# **Definition 2.3.12** The random variable's *X*$_{1}$,*X*$_{2}$,...,*X*$_{n}$ are said to form a (simple) random sample of size *n* if
# 1. The *X$_{i}$*'s are independent random variable's.
# 2. Every *X*$_{i}$ has the same probability distribution.
#
# **Proposition 2.3.13** Let *X$_{1}$, X$_{2}$,...,X$_{n}$* be a random sample from a distribution with mean value μ and standard deviation σ. Then
# 1. *E($\bar{X}$)* = μ$_\bar{X}$ = μ
# 2. *V($\bar{X}$)* = σ$_\bar{X}^{2}$ = σ$^{2}$/n and σ$_{\bar{X}}$ = σ/$\sqrt{n}$

# %%
# import random
from random import sample

# Prints list of random items of given legnth
list1 = [1, 2, 3, 4, 5]
print(sample(list1,3))
# Out:
# [4, 1, 5]

# %%
import random

# Print list of random items of length 3 from given list.
list1 = [1,2,3,4,5,6]
print("With list:", random.sample(list1, 3))

# Print list of random items of length 4  from the given list.
string = "RandomSample"
print("With strong:", random.sample(string, 4))

# Print list of random items of length 4 from given tuple.
tuple1 = ("One", "Two", "Three", "Four", "Five", "Six")
print("With tuple:", random.sample(tuple1, 4))
# Out:
# With list: [6, 4, 3]
# With strong: ['d', 'n', 'S', 'p']
# With tuple: ['Five', 'One', 'Four', 'Two']

# %% [markdown]
# **2.3.3.2 The Central Limit Theorem**
#
# **Theorem 2.3.14 (The Central Limit Theorem (CLT))** Let *X$_{1}$, X$_{2}$,..., X$_{n}$* be a random sample from a distribution with mean *μ* and varaince σ$^{2}$. Then if *n* is sufficiently large, $\bar{X}$ has approximately a normal distribution with μ$_{\bar{X}}$ = μ and σ$_{\bar{X}}^{2}$ = σ$^{2}$/ *n* and *T$_{o}$* also has approximately a normal distribution with μ$_{T_{o}}$ = *nμ*, σ$_{T_{o}}^{2}$ = *n*σ$^{2}$. The larger the value of *n*, the better the approximation.

# %%
import numpy
import matplotlib.pyplot as plt

# number of sample
num = [1, 10, 50, 100]

# list of sample means
means = []

# Generating 1, 10, 30, 100 random numbers from -40 to 40
# take the mean and appending it to list means.
for j in num:
  # generate seed so that we can get same result every time loop runs
  numpy.random.seed(1)
  x = [numpy.mean(
      numpy.random.randint(
          -40, 40, j)) for _i in range(1000)]
  means.append(x)
k = 0

# plotting all the means in one figure
fig, ax = plt.subplots(2, 2, figsize = (8,8))
for i in range(0,2):
  for j in range(0,2):
    # Histogram for each x stored in means
    ax[i, j].hist(means[k], 10, density = True)
    ax[i, j].set_title(label = num[k])
    k = k + 1
